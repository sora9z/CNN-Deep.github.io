# %% [markdown]
# # 4.3 Multi variable linear regression with file input
#
# ## 1. 실습 목적
# - 파일로부터 데이터를 입력 받는 방법을 익힌다.
#
# ## 2. 사용한 API 및 간단한 설명
# - xy=np.loadtxt('data-01-test-score.csv',delimiter=',',dtype=np.float32)
#     - data-01-test-score.csv로 부터 데이터를 입력 받음.
#     - 데이터간 구분은 ',' 콤마로 한다.
#     - 데이터 타입은 np.float32로 설정함.
#
# - x_data=xy[:,0:-1] #처음부너 마지막 이전 까지의 데이터를 배역 x_data에 저장
# - y_data=xy[:,[-1]] # 마지막 데이터를 배열 y_data에 저장
#
# - print(x_data.shape,x_data,len(x_data)) # 원하는 대로 데이터가 들어왔는지 확인
# - print(y_data.shape,y_data,len(y_data))
#
# - Training후 예측과정
#     - Training이 끝난 후에 실제 예측하는 과정을 거침
#     - 빨간색으로 표시간 부분
#     - 앞으로도 Training 이후 예측을 하는 과정이 일반적으로 젹용이 되며 궁극적으로는 training set과 test set으로 구분하면 구분 비율이 학습에 영향을 미친다.
#
# - CSV 데이터
#     - CSV : Comma Separated Value
#     - CSV 데이터는 엑셀 데이터의 특별한 형태로 콤마로 구분된 형태의 데이터

# %%
# Lab 4-3 Multi variable linear regression
import tensorflow as tf
import numpy as np

tf.set_random_seed(0)

xy=np.loadtxt('data-01-test-score.csv',delimiter=',',dtype=np.float32)

x_data=xy[:,0:-1]
y_data=xy[:,[-1]]

# check the shape and data are OK
#print(x_data.shape,x_data,len(x_data))
#print(y_data.shape,y_data,len(y_data))

# placeholders for a tensor that will be always fed.

X=tf.placeholder(tf.float32,shape=[None,3])
Y=tf.placeholder(tf.float32,shape=[None,1])

W=tf.Variable(tf.random_normal([3,1]),name='weight')
b=tf.Variable(tf.random_normal([1]),name='bias')

# Hypothesis
hypothesis=tf.matmul(X,W)+b

# cost
cost=tf.reduce_mean(tf.square(hypothesis-Y))

# Minimize
optimizer=tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train=optimizer.minimize(cost)

# Launch the graph in a session
sess=tf.Session()

# initialize 
sess.run(tf.global_variables_initializer())

for step in range(2000):
    cost_val,hy_val,_=sess.run([cost,hypothesis,train],feed_dict={X:x_data,Y:y_data})
    if step%10==0:
        print(step,'cost:',cost_val,'\nPrediction\n',hy_val)

# Ask my score
print("Your score will be",sess.run(hypothesis,feed_dict={X:[[60,70,110],[90,100,80]]}))
# Out:
# 66]
#  [181.49991]
#  [198.6696 ]
#  [141.75352]
#  [105.94988]
#  [148.74641]
#  [110.33701]
#  [175.72719]
#  [164.94606]
#  [143.37755]
#  [143.21758]
#  [186.70763]
#  [153.95555]
#  [150.0493 ]
#  [189.39589]
#  [146.55235]
#  [178.52702]
#  [177.2675 ]
#  [158.26662]
#  [174.82674]
#  [175.15573]
#  [166.07869]
#  [151.02339]
#  [191.9585 ]]
# 1470 cost: 8.005453
# Prediction
#  [[151.75862]
#  [186.0973 ]
#  [181.49986]
#  [198.67073]
#  [141.74838]
#  [105.94716]
#  [148.75084]
#  [110.34547]
#  [175.72401]
#  [164.94514]
#  [143.37865]
#  [143.21626]
#  [186.70624]
#  [153.95226]
#  [150.0529 ]
#  [189.39421]
#  [146.54579]
#  [178.53456]
#  [177.26698]
#  [158.26709]
#  [174.83055]
#  [175.15416]
#  [166.08257]
#  [151.023  ]
#  [191.95549]]
# 1480 cost: 7.995039
# Prediction
#  [[151.76123 ]
#  [186.09398 ]
#  [181.4998  ]
#  [198.67183 ]
#  [141.74327 ]
#  [105.944435]
#  [148.75523 ]
#  [110.35389 ]
#  [175.72081 ]
#  [164.94421 ]
#  [143.37975 ]
#  [143.21495 ]
# ...
